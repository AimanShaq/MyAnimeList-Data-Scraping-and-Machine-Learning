# %% [markdown]
# ## Project
#
# **Group Member**
# 1. Amir Firdaus       (A18CS0027)
# 2. Aiman Shaquan      (A18CS0021)
# 3. Ahmad Syamil Aiman (A18CS0019)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA as iskay

# %%
anime = pd.read_csv('anime.csv')
rating = pd.read_csv('rating.csv')

# %%
# View anime table
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
# View rating table
rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
# Check for null in anime table
anime.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
# Check for null in rating table
rating.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
# Drop null value from anime table
anime= anime.dropna()
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12017 rows x 7 columns]

# %%
# Drop unknown value from anime table
unknown = anime[anime['episodes']=='Unknown'].index
new_data = anime.drop(unknown)
new_data
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [11830 rows x 7 columns]

# %%
#Merge two data 
mergedata = pd.merge(new_data,rating,on=['anime_id','anime_id'])
mergedata
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 7813602      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813603      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813604      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813605     26081                   Yasuji no Pornorama: Yacchimae!!
# 7813606     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                         genre   type episodes  rating_x  \
# 0        Drama, Romance, School, Supernatural  Movie        1      9.37
# 1        Drama, Romance, School, Supernatural  Movie        1      9.37
# 2        Drama, Romance, School, Supernatural  Movie        1      9.37
# 3        Drama, Romance, School, Supernatural  Movie        1      9.37
# 4        Drama, Romance, School, Supernatural  Movie        1      9.37
# ...                                       ...    ...      ...       ...
# 7813602                                Hentai    OVA        1      4.98
# 7813603                                Hentai    OVA        1      4.98
# 7813604                                Hentai    OVA        1      4.98
# 7813605                                Hentai  Movie        1      5.46
# 7813606                                Hentai  Movie        1      5.46
#
#          members  user_id  rating_y
# 0         200630       99         5
# 1         200630      152        10
# 2         200630      244        10
# 3         200630      271        10
# 4         200630      278        -1
# ...          ...      ...       ...
# 7813602      175    39532        -1
# 7813603      175    48766        -1
# 7813604      175    60365         4
# 7813605      142    27364        -1
# 7813606      142    48766        -1
#
# [7813607 rows x 9 columns]

# %%
#since both table have column name rating, when merge it show as rating_x and rating_y
#here we change the column name

mergedata = mergedata.rename(columns={'rating_x':'rating_anime','rating_y':'rating_user'})
mergedata
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 7813602      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813603      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813604      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813605     26081                   Yasuji no Pornorama: Yacchimae!!
# 7813606     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                         genre   type episodes  rating_anime  \
# 0        Drama, Romance, School, Supernatural  Movie        1          9.37
# 1        Drama, Romance, School, Supernatural  Movie        1          9.37
# 2        Drama, Romance, School, Supernatural  Movie        1          9.37
# 3        Drama, Romance, School, Supernatural  Movie        1          9.37
# 4        Drama, Romance, School, Supernatural  Movie        1          9.37
# ...                                       ...    ...      ...           ...
# 7813602                                Hentai    OVA        1          4.98
# 7813603                                Hentai    OVA        1          4.98
# 7813604                                Hentai    OVA        1          4.98
# 7813605                                Hentai  Movie        1          5.46
# 7813606                                Hentai  Movie        1          5.46
#
#          members  user_id  rating_user
# 0         200630       99            5
# 1         200630      152           10
# 2         200630      244           10
# 3         200630      271           10
# 4         200630      278           -1
# ...          ...      ...          ...
# 7813602      175    39532           -1
# 7813603      175    48766           -1
# 7813604      175    60365            4
# 7813605      142    27364           -1
# 7813606      142    48766           -1
#
# [7813607 rows x 9 columns]

# %%
#Sort data by episodes and members
mergedata = mergedata.sort_values(by=['episodes','members'],ascending = True)
mergedata
# Out:
#          anime_id                                 name  \
# 7687556     33858                      Kissaten Soudou
# 7688221     33174                          Nori P-chan
# 7687320     33868                  Kabi Usagi: Kaichuu
# 7685913     33978                   0-sen Hayato Pilot
# 7686541     34119  Escalator-jou no Hokou no Kiken-sei
# ...           ...                                  ...
# 508142      12431                        Uchuu Kyoudai
# 508143      12431                        Uchuu Kyoudai
# 508144      12431                        Uchuu Kyoudai
# 508145      12431                        Uchuu Kyoudai
# 508146      12431                        Uchuu Kyoudai
#
#                                                 genre     type episodes  \
# 7687556                                        Comedy      ONA        1
# 7688221                           Kids, Slice of Life      OVA        1
# 7687320                                        Comedy      ONA        1
# 7685913                          Historical, Military      OVA        1
# 7686541                                         Drama  Special        1
# ...                                               ...      ...      ...
# 508142   Comedy, Sci-Fi, Seinen, Slice of Life, Space       TV       99
# 508143   Comedy, Sci-Fi, Seinen, Slice of Life, Space       TV       99
# 508144   Comedy, Sci-Fi, Seinen, Slice of Life, Space       TV       99
# 508145   Comedy, Sci-Fi, Seinen, Slice of Life, Space       TV       99
# 508146   Comedy, Sci-Fi, Seinen, Slice of Life, Space       TV       99
#
#          rating_anime  members  user_id  rating_user
# 7687556          3.46       34    53492            3
# 7688221          4.10       35    12431            3
# 7687320          4.17       36    53492            3
# 7685913          5.14       37    48766           -1
# 7686541          3.33       37    49662            5
# ...               ...      ...      ...          ...
# 508142           8.59    72958    72791           -1
# 508143           8.59    72958    72863            9
# 508144           8.59    72958    73111            8
# 508145           8.59    72958    73257            8
# 508146           8.59    72958    73376            9
#
# [7813607 rows x 9 columns]

# %%
#get the full list of all genre in the genre column

genres = ''

for genre in new_data['genre'].to_list():
    genres += str(genre) + ', '

# %%
#Seperate all the list by ,
list_genres = genres.split(', ')
genres =  genres.split(', ')

# %%
# remove duplicate in the list
genres = set(genres)

# %%
genres
# Out:
# {'',
#  'Action',
#  'Adventure',
#  'Cars',
#  'Comedy',
#  'Dementia',
#  'Demons',
#  'Drama',
#  'Ecchi',
#  'Fantasy',
#  'Game',
#  'Harem',
#  'Hentai',
#  'Historical',
#  'Horror',
#  'Josei',
#  'Kids',
#  'Magic',
#  'Martial Arts',
#  'Mecha',
#  'Military',
#  'Music',
#  'Mystery',
#  'Parody',
#  'Police',
#  'Psychological',
#  'Romance',
#  'Samurai',
#  'School',
#  'Sci-Fi',
#  'Seinen',
#  'Shoujo',
#  'Shoujo Ai',
#  'Shounen',
#  'Shounen Ai',
#  'Slice of Life',
#  'Space',
#  'Sports',
#  'Super Power',
#  'Supernatural',
#  'Thriller',
#  'Vampire',
#  'Yaoi',
#  'Yuri'}

# %%
genres.remove('')
genres
# Out:
# {'Action',
#  'Adventure',
#  'Cars',
#  'Comedy',
#  'Dementia',
#  'Demons',
#  'Drama',
#  'Ecchi',
#  'Fantasy',
#  'Game',
#  'Harem',
#  'Hentai',
#  'Historical',
#  'Horror',
#  'Josei',
#  'Kids',
#  'Magic',
#  'Martial Arts',
#  'Mecha',
#  'Military',
#  'Music',
#  'Mystery',
#  'Parody',
#  'Police',
#  'Psychological',
#  'Romance',
#  'Samurai',
#  'School',
#  'Sci-Fi',
#  'Seinen',
#  'Shoujo',
#  'Shoujo Ai',
#  'Shounen',
#  'Shounen Ai',
#  'Slice of Life',
#  'Space',
#  'Sports',
#  'Super Power',
#  'Supernatural',
#  'Thriller',
#  'Vampire',
#  'Yaoi',
#  'Yuri'}

# %%
rating_count = new_data['rating'].groupby(new_data['type'])
rating_count = rating_count.agg([('Minimum','min'),('Maximum','max'),('Average','mean'),('Count','count')])
rating_count
# Out:
#          Minimum  Maximum   Average  Count
# type
# Movie       1.92    10.00  6.334486   2258
# Music       3.28     8.38  5.588665    487
# ONA         2.67     8.26  5.640479    606
# OVA         2.00     9.25  6.371087   3246
# Special     1.67     8.66  6.525453   1665
# TV          3.00     9.26  6.929487   3568

# %%
rating_members = new_data['members'].groupby(new_data['type'])
rating_members = rating_members.agg([('Minimum','min'),('Maximum','max'),('Average','mean'),('Count','count')])
rating_members
# Out:
#          Minimum  Maximum       Average  Count
# type
# Movie         13   466254  10568.609832   2258
# Music         24    71136   1314.455852    487
# ONA           25   144898   4449.237624    606
# OVA           17   305165   6065.670364   3246
# Special       24   160423   7709.295495   1665
# TV            12  1013917  44635.572029   3568

# %%
member_count = mergedata['members'].groupby(mergedata['type'])
member_count.agg([('Minimum','min'),('Maximum','max'),('Average','mean')])
# Out:
#          Minimum  Maximum        Average
# type
# Movie         40   466254  106502.127929
# Music         55    71136   15204.001170
# ONA           31   144898   44711.133037
# OVA           35   305165   44079.750257
# Special       34   160423   42460.284575
# TV            29  1013917  230926.514012

# %%
genres_count = []
for genre in genres:
        gen = genre,list_genres.count(genre)
        genres_count.append(gen)
genres_count
df = pd.DataFrame(genres_count,columns=['Genre','Count'])
df.set_index('Genre',inplace = True)
df
# Out:
#                Count
# Genre
# Hentai          1099
# Shounen Ai        62
# Thriller          86
# Military         415
# Mecha            927
# Shoujo           587
# Slice of Life   1180
# Demons           287
# Harem            312
# Fantasy         2219
# Yaoi              37
# Josei             52
# Music            832
# Action          2748
# Super Power      445
# Horror           360
# Game             170
# Mystery          482
# Vampire          100
# Magic            742
# Shoujo Ai         54
# School          1164
# Sports           527
# Ecchi            627
# Comedy          4483
# Parody           397
# Police           194
# Sci-Fi          2028
# Drama           1972
# Psychological    226
# Space            376
# Yuri              41
# Shounen         1669
# Kids            1550
# Martial Arts     258
# Adventure       2293
# Romance         1436
# Cars              71
# Samurai          145
# Historical       787
# Dementia         238
# Supernatural     993
# Seinen           530

# %%
topgenredf = df.sort_values(by=['Count'],ascending=False)[:10]
fig, axes = plt.subplots(2, 1, figsize=(10,10))
df.plot.bar(ax=axes[0]) # count of anime genre
topgenredf.plot.bar(ax=axes[1]) # top 10 anime genre

# %%
fig, axes = plt.subplots(2, 1, figsize=(10,10))
rating_count['Average'].plot.bar(ax=axes[0]) # average rating of anime by type
rating_members['Average'].plot.bar(ax=axes[1]) # average member of anime type

# %%
topanimedf = pd.DataFrame(new_data,columns=['name','members'])
topanimedf.set_index('name',inplace = True)
topanimedf
# Out:
#                                                     members
# name
# Kimi no Na wa.                                       200630
# Fullmetal Alchemist: Brotherhood                     793665
# Gintama°                                             114262
# Steins;Gate                                          673572
# Gintama&#039;                                        151266
# ...                                                     ...
# Toushindai My Lover: Minami tai Mecha-Minami            211
# Under World                                             183
# Violence Gekiga David no Hoshi                          219
# Violence Gekiga Shin David no Hoshi: Inma Densetsu      175
# Yasuji no Pornorama: Yacchimae!!                        142
#
# [11830 rows x 1 columns]

# %%
topanime = topanimedf.sort_values(by=['members'],ascending=False)[:5]
labels = topanime.index.to_list()
plt.figure(figsize=(10,10))
plt.pie(topanime['members'], labels=labels,autopct='%1.1f%%')
_ = plt.legend(labels)

# %%
user_anime = pd.crosstab(mergedata['user_id'][:10], mergedata['name'][:10])
user_anime.head(10)

# %%
pca = iskay(n_components=4)
pca.fit(user_anime)
pca_samples = pca.transform(user_anime)
